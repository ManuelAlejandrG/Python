# %% [markdown]
# <a href="https://colab.research.google.com/github/ManuelAlejandrG/Python/blob/master/VGG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Clasificación de objetos en una imagen mediante el modelo pre entrenada VGG

# %% [markdown]
# Mostramos la imagen que está en esa ubicación

# %%
from IPython.display import Image
Image("/content/original.jpg")

# %% [markdown]
# Cargamos el modelo preentrenado de la librerias keras

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16
# load the model
model = VGG16()

# %% [markdown]
# Cargamos la imagen y la procesamos

# %%
# load an image from file

image = load_img('/content/original.jpg', target_size=(224, 224))
# convert the image pixels to a numpy array
image = img_to_array(image)
# reshape data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

# %% [markdown]
# Procesamos la imagen y hacemos la predicción

# %%
# prepare the image for the VGG model
image = preprocess_input(image)
# predict the probability across all output classes
yhat = model.predict(image)
# convert the probabilities to class labels
label = decode_predictions(yhat)
# retrieve the most likely result, e.g. highest probability
label = label[0][0]
# print the classification
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# Labrador_retriever (34.71%)
